# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
Data = pd.read_csv("1. Regression - Module - (Housing Prices).csv")

# %%
Data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %% [markdown]
# # Descriptive statistics part 1

# %%
Data.dtypes
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %%
Data.head(10)
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
# 5  7237550310         14 May 2017   1230000.0               4
# 6  1321400060        14 June 2017    257500.0               3
# 7  2008000270     15 January 2016    291850.0               3
# 8  2414600126       15 April 2016    229500.0               3
# 9  3793500160       15 March 2016    323000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# ...

# %%
Data.tail(10)
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 21603  7852140040      14 August 2017    507250.0               3
# 21604  9834201367     15 January 2016    429000.0               3
# 21605  3448900210     14 October 2017    610685.0               4
# 21606  7936000429       15 March 2016   1010000.0               4
# 21607  2997800021    15 February 2016    475000.0               3
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 21603             2.50               2270.0              5536.0           2.0
# 21604             2.00               1490.0              1126.0           3.0
# ...

# %%
Data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
Data.describe(include="all")
# Out:
#                   ID Date House was Sold    Sale Price  No of Bedrooms  \
# count   2.161300e+04               21613  2.160900e+04    21613.000000
# unique           NaN                  13           NaN             NaN
# top              NaN       15 April 2016           NaN             NaN
# freq             NaN                2231           NaN             NaN
# mean    4.580302e+09                 NaN  5.401984e+05        3.370842
# std     2.876566e+09                 NaN  3.673890e+05        0.930062
# min     1.000102e+06                 NaN  7.500000e+04        0.000000
# 25%     2.123049e+09                 NaN  3.219500e+05        3.000000
# 50%     3.904930e+09                 NaN  4.500000e+05        3.000000
# 75%     7.308900e+09                 NaN  6.450000e+05        4.000000
# max     9.900000e+09                 NaN  7.700000e+06       33.000000
#
#         No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  \
# ...

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        21613 non-null  object
# ...

# %% [markdown]
# # Descriptive Statistics of the Dataset-Part 2
# ### >> Calculate Descriptive Statistics for the individual variables in the dataset\n
# ### >> Use Numpy Library for Descriptive Statistics..

# %%
Data['Sale Price'].mean()
# Out:
# 540198.4357443658

# %%
Data['Sale Price'].min()
# Out:
# 75000.0

# %%
Data['Sale Price'].max()
# Out:
# 7700000.0

# %%
Data['Sale Price'].std()
# Out:
# 367388.99446065375

# %%
Data['Sale Price'].quantile(.25)
# Out:
# 321950.0

# %%
Data['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %% [markdown]
# # Using Numpy Library for Descriptive Statistics
# ## Numpy Library
# ### It is an essential library for mathematical calculations and contains several mathematics functions.

# %%
import numpy as np

# %%
np.std(Data['Sale Price'])
# Out:
# 367380.4935294451

# %%
Data["Sale Price"].std()
# Out:
# 367388.99446065375

# %%
Data["Sale Price"].std() - np.std(Data["Sale Price"])
# Out:
# 8.500931208662223

# %%
np.std(Data['Sale Price'], ddof=1)
# Out:
# 367388.99446065375

# %%
np.std(Data['Sale Price'])
# Out:
# 367380.4935294451

# %%
import numpy as np

# To get a list of all attributes and methods in the NumPy module
all_attributes_and_methods = dir(np)

# To get only the functions, you can filter the list
numpy_functions = [func for func in all_attributes_and_methods if callable(getattr(np, func))]

# Print the number of functions
print("Number of functions in NumPy:", len(numpy_functions))
# Out:
# Number of functions in NumPy: 503

# %%
dir(np)
# Out:
# ['ALLOW_THREADS',
#  'AxisError',
#  'BUFSIZE',
#  'Bytes0',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'Datetime64',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'MachAr',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'Str0',
#  'Tester',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'Uint64',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_NoValue',
#  '_UFUNC_API',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
# ...

# %% [markdown]
# ## Plotting Graphs
#
# # line , bar, pie

# %%
import matplotlib.pyplot as plt

# %% [raw]
# Data['Sale Price'].head(5)

# %% [raw]
# x = len(Data['Sale Price'])
# x

# %%
plt.plot(Data['Sale Price'])

# %%
plt.plot(Data['Sale Price'], color = 'green')

# %%
plt.plot(Data['Sale Price'], color = 'green')
plt.xlabel("Record Number")
plt.ylabel("Sale Price ")
plt.title("My First Graph")

# Set the scalar formatting to 'plain' to avoid scientific notation
plt.ticklabel_format(style='plain', axis='y')

plt.show()

# %%
plt.plot(Data['Sale Price'], marker='o', markerfacecolor='Blue', markersize=5,color='green',linewidth=5,linestyle='dashed')

# %% [markdown]
# ## "Grouping "
# ### the data means finding count of records in each of the unique values of a variable.

# %%
# The "Groupby" Function groups the categorical or string variables.
Data.groupby('Condition of the House')['ID'].count()
# Out:
# Condition of the House
# Bad             30
# Excellent     1701
# Fair         14031
# Good          5679
# Okay           172
# Name: ID, dtype: int64

# %%
values=(30,1701,14031,5679,172)

# %%
labels=('Bad','Excellent','Fair','Good','Okay')

# %%
plt.pie(values, labels = labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x25ca9bb9f70>,
# ...
#  [Text(1.099989541385049, 0.004796753434368107, 'Bad'),
#   Text(1.0641591373844368, 0.27850553014475643, 'Excellent'),
#   Text(-0.9085709380486652, 0.620079713047741, 'Fair'),
#   Text(0.7046888223897579, -0.8446381850229934, 'Good'),
#   Text(1.0996562341282203, -0.02749848619362501, 'Okay')])

# %%
plt.bar(labels, values, color = 'Blue' )
# Out:
# <BarContainer object of 5 artists>

# %%
plt.bar(labels, values, color ='Blue', linewidth =5, linestyle ='dashed')
plt.xlabel("Condition of the House")
plt.ylabel("Count of the House")
plt.title("My first bar graph")
plt.show()

# %% [markdown]
# # Scatter plot, Histogram, and Box Plot

# %%
plt.scatter (x= Data['Flat Area (in Sqft)'],
             y = Data['Sale Price'], color = 'red')
plt.xlabel("Area")
plt.ylabel("Selling price")
plt.title("Selling price vs Area")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(x = Data['No of Bathrooms'], y = Raw_Housing_Data['Sale Price'], color = 'red')
plt.xlabel("No of Bathrooms")
plt.ylabel("Selling Price")
plt.title("Selling Price vs No of Bathrooms")
plt.show()

# %%
plt.scatter(x = Data['Age of House (in Years)'], y = Raw_Housing_Data['Sale Price'], color= 'red')
plt.xlabel("Age of House")
plt.ylabel("Selling Price")
plt.title("Selling Price vs Age of House")
plt.show()

# %% [markdown]
# ### Histogram is used to plot frequency count (or simply count of records) over the range of values a variable can have.

# %%
Data.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# ...

# %%
plt.hist(Data['Age of House (in Years)'], bins = 10)
# Out:
# (array([3592., 2663., 2784., 2525., 3218., 2587., 1361., 1079.,  952.,
#          852.]),
#  array([  3. ,  14.5,  26. ,  37.5,  49. ,  60.5,  72. ,  83.5,  95. ,
#         106.5, 118. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(Data['Age of House (in Years)'], bins=10)
plt.xlabel("Age of House(in Years)")
plt.ylabel("No of Records")
plt.title("Age Wise Distribution of Houses")
plt.show()

# %% [markdown]
# ## There are more houses which were newer and lesser in age compared to number of houses which are older..

# %%
plt.boxplot(Data['Age of House (in Years)'])
# This boxplot will tell us. that Data is more skewed or centred around lower values than higher values..
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x25ca536e7f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x25ca536ee50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x25ca536e520>],
#  'medians': [<matplotlib.lines.Line2D at 0x25ca537c370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x25ca537c640>],
#  'means': []}

# %% [markdown]
# # Data Visualisation - A Tip
# ### Don't create graphs for the sake of it, always start with a specific question that you can want to answer or specific information that you want to find and then think of the most appropriate graph for that question

# %% [markdown]
# # Pandas and Numpy functions to calculate Mean, Median, and Mode
# #### DataFrame.mean() or np.mean
# #### DataFrame.median() or np.median
# #### Dataframe.mode() etc...

# %% [markdown]
# # Basic pandas and numpy functions to:
# #### --> Import the data
# #### --> Explore the data
# #### --> Calculate descriptive statistics of the data
# #### --> Visualise the data.

# %% [markdown]
# # The pandas.groupby() function

# %%
data = pd.read_csv("1. Regression - Module - (Housing Prices).csv")

# %%
data['Sale Price'].mean()
# Out:
# 540198.4357443658

# %%
#Initialising a new column
data['condition_sale'] = 0

#Calculation mean based on the condition of the House
for i in data['Condition of the House'].unique():
    data['condition_sale'][data['Condition of the House'] == str(i)] = data['Sale Price'][data['Condition of the House'] == str (i)].mean()
#     print(data['condition_sale'])
    
# Plotting the mean sales based on the Condition of the House
plt.figure( dpi =100)
plt.bar(data['Condition of the House'].unique(), data['condition_sale'].unique())
plt.xlabel("Condition of the House")
plt.ylabel("Mean Sale Price")
plt.show()

# %%
data['condition_sale'].unique()
# Out:
# array([542130.61120616, 612577.74250441, 521277.5105671 , 334431.66666667,
#        327316.21511628])

# %%
data['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
data['Zipcode'].unique()
# Out:
# array([98178., 98125., 98028., 98136., 98074., 98053., 98003., 98198.,
#        98146., 98038., 98007., 98115., 98107., 98126., 98019., 98103.,
#        98002., 98133., 98040., 98092., 98030., 98119., 98112., 98052.,
#        98027., 98117., 98058., 98001., 98056., 98166., 98023., 98070.,
#        98148., 98105., 98042., 98008., 98059., 98122., 98144., 98004.,
#        98005., 98034., 98075., 98116., 98010., 98118., 98199., 98032.,
#        98045., 98102., 98077., 98108., 98168., 98177., 98065., 98029.,
#        98006., 98109., 98022., 98033., 98155., 98024., 98011., 98031.,
#        98106., 98072., 98188., 98014., 98055.,    nan, 98039.])

# %%
#Initialising a new column
data['zip_condition_sale'] = 0

C = 'Condition of the House'
Z = 'Zipcode'

# Calculating mean based on the condition of the House and zipcode
for i in data[C].unique():
    for j in data[Z].unique():
        data['zip_condition_sale'][(data[C] == str(i)) & (data[Z] == j)] = data['Sale Price'][(data[C] ==str(i)) & (data[Z] ==j)].mean()
        
len(data['zip_condition_sale'].unique())
# Out:
# 281

# %% [raw]
# The above code is inefficient .

# %% [markdown]
# # Advanced Functions of Pandas Library
# -- pandas.groupby()
#
# -- pandas.pivot_table()
#
# ## Limitations of pandas.groupby():
# --- It cannot perform very complex aggregations.
#
# --- The format cannot be changed to suit our needs.

# %% [markdown]
# # Syntax of groupby():
#
# dataframe.groupby(["list of columns to group by"])["Column to be grouped"].how_to_be_group()

# %%
zip_condition_sale = data.groupby(['Condition of the House', 'Zipcode'])['Sale Price'].mean()

zip_condition_sale
# Out:
# Condition of the House  Zipcode
# Bad                     98004.0    1.500000e+06
#                         98006.0    3.725000e+05
#                         98011.0    2.700000e+05
#                         98023.0    1.500000e+05
#                         98024.0    1.420000e+05
#                                        ...
# Okay                    98155.0    3.601833e+05
#                         98166.0    2.165625e+05
#                         98168.0    1.809389e+05
#                         98178.0    1.750000e+05
#                         98198.0    2.705325e+05
# Name: Sale Price, Length: 283, dtype: float64

# %% [markdown]
#  #                                          # pandas.pivot_table():
# --- It can easily handle more complex operation.
#
# --- It provides better representation.
#
# ### Benefits:
# ---- Shorter and more comprehensibile code
#
# ---- Cleaner representation

# %%
zipcode_condition_sale2 = pd.pivot_table(data, index=["Condition of the House", "Zipcode"], values=["Sale Price"], aggfunc=np.mean)

zipcode_condition_sale2
# Out:
#                                   Sale Price
# Condition of the House Zipcode
# Bad                    98004.0  1.500000e+06
#                        98006.0  3.725000e+05
#                        98011.0  2.700000e+05
#                        98023.0  1.500000e+05
#                        98024.0  1.420000e+05
# ...                                      ...
# Okay                   98155.0  3.601833e+05
#                        98166.0  2.165625e+05
#                        98168.0  1.809389e+05
#                        98178.0  1.750000e+05
#                        98198.0  2.705325e+05
#
# [283 rows x 1 columns]

# %%
zipcode_condition_sale3 = pd.pivot_table(data, index=["Zipcode"],columns=["Condition of the House"], values=["Sale Price"], aggfunc=np.mean)

zipcode_condition_sale3
# Out:
#                        Sale Price                                            \
# Condition of the House        Bad     Excellent          Fair          Good
# Zipcode
# 98001.0                       NaN  2.425433e+05  2.927207e+05  2.527446e+05
# 98002.0                       NaN  2.216411e+05  2.588868e+05  2.192858e+05
# 98003.0                       NaN  3.706800e+05  2.992801e+05  2.809591e+05
# 98004.0                 1500000.0  1.236365e+06  1.527265e+06  1.145915e+06
# 98005.0                       NaN  8.319500e+05  8.668012e+05  7.669397e+05
# ...                           ...           ...           ...           ...
# 98177.0                       NaN  8.966313e+05  6.496812e+05  6.665755e+05
# 98178.0                       NaN  2.975217e+05  3.094105e+05  3.308419e+05
# 98188.0                       NaN  2.853636e+05  2.900059e+05  2.867413e+05
# 98198.0                       NaN  3.215235e+05  2.941619e+05  3.154305e+05
# ...

# %%
data.head(30)
# Out:
#             ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0   7129300520     14 October 2017    221900.0               3
# 1   6414100192    14 December 2017    538000.0               3
# 2   5631500400    15 February 2016    180000.0               2
# 3   2487200875    14 December 2017    604000.0               4
# 4   1954400510    15 February 2016    510000.0               3
# 5   7237550310         14 May 2017   1230000.0               4
# 6   1321400060        14 June 2017    257500.0               3
# 7   2008000270     15 January 2016    291850.0               3
# 8   2414600126       15 April 2016    229500.0               3
# 9   3793500160       15 March 2016    323000.0               3
# 10  1736800520       15 April 2016    662500.0               3
# 11  9212900260         14 May 2017    468000.0               2
# 12   114101516         14 May 2017    310000.0               3
# 13  6054650070     14 October 2017    400000.0               3
# ...

# %%
data['plot_length'] = data['Flat Area (in Sqft)']**0.5
data['plot_length'].head()
# Out:
# 0    34.351128
# 1    50.695167
# 2    27.748874
# 3    44.271887
# 4    40.987803
# Name: plot_length, dtype: float64

# %%
data ['total_area'] = data['Flat Area (in Sqft)']+ data ['Lot Area (in Sqft)']

data['total_area'].head()
# Out:
# 0     6830.0
# 1     9812.0
# 2    10770.0
# 3     6960.0
# 4     9760.0
# Name: total_area, dtype: float64

# %%
data['Condition of the House'][data['Condition of the House'] =='Fair'] ='1'
data['Condition of the House'][data['Condition of the House'] =='Okay'] ='0'
data['Condition of the House'][data['Condition of the House'] =='Bad'] ='0'
data['Condition of the House'][data['Condition of the House'] =='Good'] ='1'
data['Condition of the House'][data['Condition of the House'] =='Excellent'] ='3'
data['Condition of the House'].unique()
# Out:
# array([nan], dtype=object)

# %% [markdown]
# # Pandas.map():
# --- Limitation- It is work only one column at a time..

# %%
data['Condition of the House'] = data['Condition of the House'].map({'Good':'1',
                                                                     'Excellent':'3',
                                                                     'Bad': '0',
                                                                     'Fair':'1',
                                                                     'Okay':'0'})
data['Condition of the House'].unique()
# Out:
# array([nan], dtype=object)

# %%
year =[]
for i in range(len(data['Date House was Sold'])):
    k = data['Date House was Sold'][i].split()[-1]
    year.append(k)
    
data['year_sold']  = year
data['year_sold'].head()
# Out:
# 0    2017
# 1    2017
# 2    2016
# 3    2017
# 4    2016
# Name: year_sold, dtype: object

# %%
def year(value):
    return value.split()[-1]
data['year_sold'] =data['Date House was Sold'].map(year)
data['year_sold'].head ()
# Out:
# 0    2017
# 1    2017
# 2    2016
# 3    2017
# 4    2016
# Name: year_sold, dtype: object

# %% [markdown]
# # pandas.apply(): Function

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# Problem Statement:
#     A house can be called a luxury home if any two of the three conditions are met::
#             1. "Condition of the House" id either good or excellent.
#             2. "Overall Grade " is greater than or equal to 8
#             3. "Waterfront View" is present

# %%
data['luxury_home'] = '0'
for i in range (len(data)):
    count = 0
    if data['Waterfront View'][i] =='Yes':
        count = count+1
    if data['Condition of the House'] [i] in['Good', 'Excellent']:
        count = count+1
    if data['Overall Grade'][i] >=8:
        count = count+1
    if count>=2:
        data['luxury_home'][i] ='Yes'
    else:
        data['luxury_home'][i] ='No'
data['luxury_home'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
def luxury_home(row):
   count = 0
   if row[0]=='Yes':
         count=count+1
   if row[1] in['Good', 'Excellent']:
        count = count+1
   if row[2] >=8:
        count = count+1
   if count >=2:
        return 'Yes'
   else:
        return "No"
data ['luxury_home'] = data[['Waterfront View', 'Condition of the House', 'Overall Grade']].apply(luxury_home, axis = 1)
    
data['luxury_home'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %% [markdown]
# # Quiz

# %%
import pandas as pd
df2 = pd.DataFrame({'X': ['B', 'B', 'A', 'A'], 'Y': [1,2,3,4]})

# %%
df2
# Out:
#    X  Y
# 0  B  1
# 1  B  2
# 2  A  3
# 3  A  4

# %%
df2.groupby(['Y','X']).sum()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(1, B), (2, B), (3, A), (4, A)]

# %%
train_set = np.array([1,2,3])
test_set = np.array([[0,1,2], [1,2,3]])

# %%
resulting_set = np.vstack([train_set, test_set])

# %%
print(resulting_set)
# Out:
# [[1 2 3]
#  [0 1 2]
#  [1 2 3]]

# %%
L1 = list()
L1.append([2,[5,6],4])
L1.extend([4,1,3])

# %%
print(L1)
print(L1[0])
print(L1[0][0])
L1[0][1][1]+ L1[2]
# Out:
# [[2, [5, 6], 4], 4, 1, 3]
# [2, [5, 6], 4]
# 2
# 7
